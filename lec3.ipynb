# %% [markdown]
# singly linked list ->array mai countiguous memeory allocation(array is used as container)

# %% [markdown]
# in a python block alloted partion of store
# 1st is inforamtion and 2nd is next location address

# %% [markdown]
# head and temp store in info and next is temp and it is one way directional

# %% [markdown]
# head.info
# head.next
# head.next.info
# head.next.next

# %% [markdown]
# important is head.next and head.info

# %% [markdown]
# while(temp.next!=none):
# temp = temp.next
#
# and those who is create the object in name is ->self

# %%
class node:
  def __init__(self,info,next=None):
    self.data = info
    self.next = next

# %%
class node:
  def __init__(self,info,next=None):
    self.data = info
    self.next = next

class singlylinkedlist:
  def __init__(self,head = None):
    self.head = head
  def insertatend(self,value):
    temp = node.value

# %%
class node:
  def __init__(self,info,next=None):
    self.data = info
    self.next = next

class singlylinkedlist:
  def __init__(self,head = None):
    self.head = head
  def insertatend(self,value):
    new_node = node(value) # Create the new node
    if self.head is None: # If the list is empty
      self.head = new_node # The new node becomes the head
    else: # If the list is not empty
      current = self.head # Start from the head
      while current.next is not None: # Traverse to the last node
        current = current.next
      current.next = new_node # Append the new node

# %%
class node:
  def __init__(self,info,next=None):
    self.data = info
    self.next = next

class singlylinkedlist:
  def __init__(self,head = None):
    self.head = head
  def insertatend(self,value):
    new_node = node(value) # Create the new node
    if self.head is None: # If the list is empty
      self.head = new_node # The new node becomes the head
    else: # If the list is not empty
      current = self.head # Start from the head
      while current.next is not None: # Traverse to the last node
        current = current.next
      current.next = new_node # Append the new node

# %%
class node:
  def __init__(self,info,next=None):
    self.data = info
    self.next = next

class singlylinkedlist:
  def __init__(self,head = None):
    self.head = head
  def insertatend(self,value):
    new_node = node(value) # Create the new node
    if self.head is None: # If the list is empty
      self.head = new_node # The new node becomes the head
    else: # If the list is not empty
      current = self.head # Start from the head
      while current.next is not None: # Traverse to the last node
        current = current.next
      current.next = new_node # Append the new node

# %%
class node:
  def __init__(self,info,next=None):
    self.data = info
    self.next = next

class singlylinkedlist:
  def __init__(self,head = None):
    self.head = head

  def insertatend(self,value):
    new_node = node(value) # Create the new node
    if self.head is None: # If the list is empty
      self.head = new_node # The new node becomes the head
    else: # If the list is not empty
      current = self.head # Start from the head
      while current.next is not None: # Traverse to the last node
        current = current.next
      current.next = new_node # Append the new node

  def printll(self):
    t1 = self.head
    if t1 is None:
      print("List is empty")
      return
    while(t1 is not None):
      print(t1.data, end=" -> ")
      t1 = t1.next
    print("None")

# %%
class node:
  def __init__(self,info,next=None):
    self.data = info
    self.next = next

class singlylinkedlist:
  def __init__(self,head = None):
    self.head = head

  def insertatend(self,value):
    new_node = node(value) # Create the new node
    if self.head is None: # If the list is empty
      self.head = new_node # The new node becomes the head
    else: # If the list is not empty
      current = self.head # Start from the head
      while current.next is not None: # Traverse to the last node
        current = current.next
      current.next = new_node # Append the new node

  def printll(self):
    t1 = self.head
    if t1 is None:
      print("List is empty")
      return
    while(t1 is not None):
      print(t1.data, end=" -> ")
      t1 = t1.next
    print("None")

# Example usage:
obj = singlylinkedlist()
obj.insertatend(10)
obj.insertatend(20)
obj.insertatend(30)
obj.insertatend(40)
obj.printll()
# Out:
# 10 -> 20 -> 30 -> 40 -> None

# %%
class node:
  def __init__(self,info,next=None):
    self.data = info
    self.next = next

class singlylinkedlist:
  def __init__(self,head = None):
    self.head = head

  def insertatend(self,value):
    new_node = node(value) # Create the new node
    if self.head is None: # If the list is empty
      self.head = new_node # The new node becomes the head
    else: # If the list is not empty
      current = self.head # Start from the head
      while current.next is not None: # Traverse to the last node
        current = current.next
      current.next = new_node # Append the new node

  def insertatbeg(self,value):
    new_node = node(value)
    new_node.next = self.head
    self.head = new_node

  def printll(self):
    t1 = self.head
    if t1 is None:
      print("List is empty")
      return
    while(t1 is not None):
      print(t1.data, end=" -> ")
      t1 = t1.next
    print("None")

# Example usage:
obj = singlylinkedlist()
obj.insertatend(10)
obj.insertatend(20)
obj.insertatend(30)
obj.insertatend(40)
obj.insertatbeg(5)
obj.printll()
# Out:
# 5 -> 10 -> 20 -> 30 -> 40 -> None

# %%
class node:
  def __init__(self,info,next=None):
    self.data = info
    self.next = next

class singlylinkedlist:
  def __init__(self,head = None):
    self.head = head

  def insertatend(self,value):
    new_node = node(value) # Create the new node
    if self.head is None: # If the list is empty
      self.head = new_node # The new node becomes the head
    else: # If the list is not empty
      current = self.head # Start from the head
      while current.next is not None: # Traverse to the last node
        current = current.next
      current.next = new_node # Append the new node

  def insertatbeg(self,value):
    new_node = node(value)
    new_node.next = self.head
    self.head = new_node

  def inserinmiddele(self,value,x): # Inserts 'value' after 'x'
    new_node = node(value)
    if self.head is None:
      print("List is empty, cannot insert in middle.")
      return

    current = self.head
    while current is not None:
      if current.data == x:
        new_node.next = current.next
        current.next = new_node
        return # Inserted, so exit
      current = current.next
    print(f"Value {x} not found in the list. Cannot insert {value}.")

  def printll(self):
    t1 = self.head
    if t1 is None:
      print("List is empty")
      return
    while(t1 is not None):
      print(t1.data, end=" -> ")
      t1 = t1.next
    print("None")

# Example usage:
obj = singlylinkedlist()
obj.insertatend(10)
obj.insertatend(20)
obj.insertatend(30)
obj.insertatend(40)
obj.insertatbeg(50)
obj.inserinmiddele(60,30) # Insert 60 after 30
obj.printll()
# Out:
# 50 -> 10 -> 20 -> 30 -> 60 -> 40 -> None

# %%
class node:
  def __init__(self,info,next=None):
    self.data = info
    self.next = next

class singlylinkedlist:
  def __init__(self,head = None):
    self.head = head

  def insertatend(self,value):
    new_node = node(value) # Create the new node
    if self.head is None: # If the list is empty
      self.head = new_node # The new node becomes the head
    else: # If the list is not empty
      current = self.head # Start from the head
      while current.next is not None: # Traverse to the last node
        current = current.next
      current.next = new_node # Append the new node

  def insertatbeg(self,value):
    new_node = node(value)
    new_node.next = self.head
    self.head = new_node

  def inserinmiddele(self,value,x): # Inserts 'value' after 'x'
    new_node = node(value)
    if self.head is None:
      print("List is empty, cannot insert in middle.")
      return

    current = self.head
    while current is not None:
      if current.data == x:
        new_node.next = current.next
        current.next = new_node
        return # Inserted, so exit
      current = current.next
    print(f"Value {x} not found in the list. Cannot insert {value}.")

  def deletell(self,value):
    current = self.head
    prev = None

    # Case 1: Head node itself holds the value to be deleted
    if current is not None and current.data == value:
      self.head = current.next
      current = None # Delete the node
      return

    # Search for the value to be deleted, keep track of the previous node
    while current is not None and current.data != value:
      prev = current
      current = current.next

    # If value was not present in linked list
    if current is None:
      print(f"Value {value} not found in the list.")
      return

    # Unlink the node from linked list
    prev.next = current.next
    current = None # Delete the node

  def printll(self):
    t1 = self.head
    if t1 is None:
      print("List is empty")
      return
    while(t1 is not None):
      print(t1.data, end=" -> ")
      t1 = t1.next
    print("None")

# Example usage:
obj = singlylinkedlist()
obj.insertatend(10)
obj.insertatend(20)
obj.insertatend(30)
obj.insertatend(40)
obj.insertatbeg(50)
obj.inserinmiddele(60,30) # Insert 60 after 30
obj.deletell(10)
obj.printll()
obj.deletell(70) # Test deleting non-existent value
obj.printll()
# Out:
# 50 -> 20 -> 30 -> 60 -> 40 -> None
# Value 70 not found in the list.
# 50 -> 20 -> 30 -> 60 -> 40 -> None
