# %% [markdown]
# #what is data structure and algorithme

# %% [markdown]
# data - set of information
# structure- store the information

# %% [markdown]
# structure- store a information

# %% [markdown]
#   structure-
#     [array,linked list,stack,queue]->linear structure
#     [tree,graph]->non-linear structure

# %% [markdown]
# alogorithme- set of instruction

# %% [markdown]
# time and complexity- (compare a program)

# %% [markdown]
# 1<log(logn)<logn<n<n^2<n^3<......<2^n
#
# n= size of input(if n is very large)

# %% [markdown]
# mathmatical eqution-
# constant function
# linear function
# quardenic function
# cubic function
# logarmtic function
# expontial function
# constant function

# %% [markdown]
# type of anylysis-
# ex- to make a home
# -minimum 3 month
# - avarage 7 month
# - maximum 12 month

# %% [markdown]
# 1)best case- minimum time(Ω)- omega notation
# 2)avg case- avg time(θ)- thetha notation
# 3)worst case- worst time(O)- big O notation

# %% [markdown]
# 1)constant time- O(1)->denote
#
# <!-- x=5
# print(x) -->
# <!--
# if(x==5):
# print("hello)
# else:
# print("welcome") -->

# %% [markdown]
# 2) linear time- y=2n+1=> O(n)
# <!--
# n=5
# for i in range(0,n):
# print(i)
# for j in range(0,n):
# print(j) -->
# O(n)+O(n)=> so the data is O(n)

# %% [markdown]
# 3) Quradic time = 2n^2+3n+5 =>O(n^2)
# <!--
# n=5   #1unit
# m=10  #1unit -->
# print(n+m)->1unit
# <!--
# for i in range(1,n):  ->ntimes
# for i in range(0,m):    ->m times
# print("jai shree shyam") -->n*m times or n*n times
# <!--
# means 3+n^2 times but => n^2 times its time complexity -->

# %% [markdown]
# <!-- 4) qubic time-
# n =5   ->O(1)
# m=10   ->O(1)
# print(n+m) -->O(1)
# <!--
# for i in range(0,n):  =>n unit
# for j in range(0,m):  =>m unit
# for k in range(o,n):  =>n unit
# print("merge")    =>n*m*n unit or n*n*n unit O(n^3)
#
# for i in range a(0,m):
# print("shark tank)   =>m unit
#
# O(n^3+n+1)= O(n^3) -->

# %% [markdown]
# <!-- 5)logartime time=
# n =10
# while(n>=1):
# print("hello")
# n = n//2 -->
# <!--
# let k times O(k)
# n/2,n/2^2,n/2^3------------n/2^k = 1
# both side log conclude
# n = 2^k
# log n = klog2
# k = log n/log 2
# k = logn -->

# %% [markdown]
# <!-- 6)n =10
# print(n) ->1 unit -->
# <!--
# for i in range(0,n):
# print("hello") ->n unit
#
# for j in range(0,n-1):
# for k in range(0,n-2):
# print("Adarsh")       =>n^2
#
# while(n>=2):
# print("Jai Shri Shyam)
# n = n//2 =>O(logn) -->
#
# <!--
# 1+n+n^2+log n=> so greter order is n^2 so time complexity in n^2 -->
